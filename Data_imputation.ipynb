# %% [markdown]
# # Data Imputation
# - Temperature has the highest % of missing values at 47%
# - Removed any counties that were missing values over all of the recorded dates
#     - 744 counties from 1877 were removed (40%)
# - Used SimpleImputer for categorical features
# - Used KNN imputation for numeric features
# - Imputed using non-missing values from columns

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

# %%
data = pd.read_csv("/Users/Huey.ts/Desktop/STAT_390/data/data_final/us-covid-raw-data.csv")

# %%
# NULL Values
null = data.isnull().sum()
null[null != 0]
# Out:
# social_distancing_total_grade              122020
# social_distancing_visitation_grade         324202
# social_distancing_encounters_grade         122020
# social_distancing_travel_distance_grade    122020
# daily_state_test                           132248
# precipitation                              256910
# temperature                                352950
# ventilator_capacity_ratio                   14340
# icu_beds_ratio                              14340
# Religious_congregation_ratio                  478
# percent_insured                               239
# deaths_per_100000                           20076
# dtype: int64

# %%
# Percent % of NULL Values
null_per = data.isnull().mean()*100
null_per[null_per != 0]
# Out:
# social_distancing_total_grade              16.249011
# social_distancing_visitation_grade         43.172938
# social_distancing_encounters_grade         16.249011
# social_distancing_travel_distance_grade    16.249011
# daily_state_test                           17.611041
# precipitation                              34.211879
# temperature                                47.001217
# ventilator_capacity_ratio                   1.909612
# icu_beds_ratio                              1.909612
# Religious_congregation_ratio                0.063654
# percent_insured                             0.031827
# deaths_per_100000                           2.673456
# dtype: float64

# %%
null_features = [null_per[null_per != 0].index]

# %% [markdown]
# ## Found and removed counties that were missing values over all of the recorded dates

# %%
null_dat = data.groupby("county_name", dropna=False).apply(lambda x: x.isnull().mean()*100)
null_dat
# Out:
#                            date  county_fips  county_name  state_fips  \
# county_name
# Abbeville County            0.0          0.0          0.0         0.0
# Acadia Parish               0.0          0.0          0.0         0.0
# Accomack County             0.0          0.0          0.0         0.0
# Ada County                  0.0          0.0          0.0         0.0
# Adair County                0.0          0.0          0.0         0.0
# ...                         ...          ...          ...         ...
# Yukon-Koyukuk Census Area   0.0          0.0          0.0         0.0
# Yuma County                 0.0          0.0          0.0         0.0
# Zapata County               0.0          0.0          0.0         0.0
# Zavala County               0.0          0.0          0.0         0.0
# Ziebach County              0.0          0.0          0.0         0.0
#
#                            state_name  covid_19_confirmed_cases  \
# county_name
# Abbeville County                  0.0                       0.0
# Acadia Parish                     0.0                       0.0
# Accomack County                   0.0                       0.0
# Ada County                        0.0                       0.0
# Adair County                      0.0                       0.0
# ...                               ...                       ...
# Yukon-Koyukuk Census Area         0.0                       0.0
# Yuma County                       0.0                       0.0
# Zapata County                     0.0                       0.0
# Zavala County                     0.0                       0.0
# Ziebach County                    0.0                       0.0
#
#                            covid_19_deaths  social_distancing_total_grade  \
# county_name
# Abbeville County                       0.0                      13.807531
# Acadia Parish                          0.0                      13.807531
# Accomack County                        0.0                      13.807531
# Ada County                             0.0                      13.807531
# Adair County                           0.0                      13.807531
# ...                                    ...                            ...
# Yukon-Koyukuk Census Area              0.0                     100.000000
# Yuma County                            0.0                      13.807531
# Zapata County                          0.0                      13.807531
# Zavala County                          0.0                      13.807531
# Ziebach County                         0.0                     100.000000
#
#                            social_distancing_visitation_grade  \
# county_name
# Abbeville County                                   100.000000
# Acadia Parish                                       13.807531
# Accomack County                                     13.807531
# Ada County                                          13.807531
# Adair County                                        56.903766
# ...                                                       ...
# Yukon-Koyukuk Census Area                          100.000000
# Yuma County                                         56.903766
# Zapata County                                       13.807531
# Zavala County                                      100.000000
# Ziebach County                                     100.000000
#
#                            social_distancing_encounters_grade  ...  age_45_49  \
# county_name                                                    ...
# Abbeville County                                    13.807531  ...        0.0
# Acadia Parish                                       13.807531  ...        0.0
# Accomack County                                     13.807531  ...        0.0
# Ada County                                          13.807531  ...        0.0
# Adair County                                        13.807531  ...        0.0
# ...                                                       ...  ...        ...
# Yukon-Koyukuk Census Area                          100.000000  ...        0.0
# Yuma County                                         13.807531  ...        0.0
# Zapata County                                       13.807531  ...        0.0
# Zavala County                                       13.807531  ...        0.0
# Ziebach County                                     100.000000  ...        0.0
#
#                            age_50_54  age_55_59  age_60_64  age_65_69  \
# county_name
# Abbeville County                 0.0        0.0        0.0        0.0
# Acadia Parish                    0.0        0.0        0.0        0.0
# Accomack County                  0.0        0.0        0.0        0.0
# Ada County                       0.0        0.0        0.0        0.0
# Adair County                     0.0        0.0        0.0        0.0
# ...                              ...        ...        ...        ...
# Yukon-Koyukuk Census Area        0.0        0.0        0.0        0.0
# Yuma County                      0.0        0.0        0.0        0.0
# Zapata County                    0.0        0.0        0.0        0.0
# Zavala County                    0.0        0.0        0.0        0.0
# Ziebach County                   0.0        0.0        0.0        0.0
#
#                            age_70_74  age_75_79  age_80_84  age_85_or_higher  \
# county_name
# Abbeville County                 0.0        0.0        0.0               0.0
# Acadia Parish                    0.0        0.0        0.0               0.0
# Accomack County                  0.0        0.0        0.0               0.0
# Ada County                       0.0        0.0        0.0               0.0
# Adair County                     0.0        0.0        0.0               0.0
# ...                              ...        ...        ...               ...
# Yukon-Koyukuk Census Area        0.0        0.0        0.0               0.0
# Yuma County                      0.0        0.0        0.0               0.0
# Zapata County                    0.0        0.0        0.0               0.0
# Zavala County                    0.0        0.0        0.0               0.0
# Ziebach County                   0.0        0.0        0.0               0.0
#
#                            immigrant_student_ratio
# county_name
# Abbeville County                               0.0
# Acadia Parish                                  0.0
# Accomack County                                0.0
# Ada County                                     0.0
# Adair County                                   0.0
# ...                                            ...
# Yukon-Koyukuk Census Area                      0.0
# Yuma County                                    0.0
# Zapata County                                  0.0
# Zavala County                                  0.0
# Ziebach County                                 0.0
#
# [1877 rows x 58 columns]

# %%
counties = []
for i in null_features:
    counties.append(null_dat.iloc[np.where(null_dat[i] == 100)[0]].index)

# %%
counties = np.concatenate(counties)
counties = np.unique(counties)

# %%
# Number of counties to remove
len(counties)
# Out:
# 744

# %%
new_data = data.loc[~data["county_name"].isin(counties)].reset_index()
new_data
# Out:
#          index      date  county_fips        county_name  state_fips  \
# 0          239  01/22/20         1003     Baldwin County           1
# 1          240  01/23/20         1003     Baldwin County           1
# 2          241  01/24/20         1003     Baldwin County           1
# 3          242  01/25/20         1003     Baldwin County           1
# 4          243  01/26/20         1003     Baldwin County           1
# ...        ...       ...          ...                ...         ...
# 557821  749977  09/12/20        56037  Sweetwater County          56
# 557822  749978  09/13/20        56037  Sweetwater County          56
# 557823  749979  09/14/20        56037  Sweetwater County          56
# 557824  749980  09/15/20        56037  Sweetwater County          56
# 557825  749981  09/16/20        56037  Sweetwater County          56
#
#        state_name  covid_19_confirmed_cases  covid_19_deaths  \
# 0         Alabama                       0.0              0.0
# 1         Alabama                       0.0              0.0
# 2         Alabama                       0.0              0.0
# 3         Alabama                       0.0              0.0
# 4         Alabama                       0.0              0.0
# ...           ...                       ...              ...
# 557821    Wyoming                       0.0              0.0
# 557822    Wyoming                       0.0              0.0
# 557823    Wyoming                       0.0              0.0
# 557824    Wyoming                       0.0              0.0
# 557825    Wyoming                       0.0              0.0
#
#        social_distancing_total_grade social_distancing_visitation_grade  ...  \
# 0                                NaN                                NaN  ...
# 1                                NaN                                NaN  ...
# 2                                NaN                                NaN  ...
# 3                                NaN                                NaN  ...
# 4                                NaN                                NaN  ...
# ...                              ...                                ...  ...
# 557821                            D+                                  F  ...
# 557822                            D+                                  F  ...
# 557823                            D+                                  F  ...
# 557824                            D+                                  F  ...
# 557825                            D+                                  F  ...
#
#        age_45_49 age_50_54  age_55_59  age_60_64  age_65_69  age_70_74  \
# 0              7         7          7          7          6          4
# 1              7         7          7          7          6          4
# 2              7         7          7          7          6          4
# 3              7         7          7          7          6          4
# 4              7         7          7          7          6          4
# ...          ...       ...        ...        ...        ...        ...
# 557821         7         8          7          5          3          2
# 557822         7         8          7          5          3          2
# 557823         7         8          7          5          3          2
# 557824         7         8          7          5          3          2
# 557825         7         8          7          5          3          2
#
#         age_75_79  age_80_84  age_85_or_higher  immigrant_student_ratio
# 0               3          2                 2                 0.021048
# 1               3          2                 2                 0.021048
# 2               3          2                 2                 0.021048
# 3               3          2                 2                 0.021048
# 4               3          2                 2                 0.021048
# ...           ...        ...               ...                      ...
# 557821          1          1                 1                 0.025714
# 557822          1          1                 1                 0.025714
# 557823          1          1                 1                 0.025714
# 557824          1          1                 1                 0.025714
# 557825          1          1                 1                 0.025714
#
# [557826 rows x 59 columns]

# %% [markdown]
# ## Imputation

# %%
pd.DataFrame(data.dtypes).loc[null_features[0]]
# Out:
#                                                0
# social_distancing_total_grade             object
# social_distancing_visitation_grade        object
# social_distancing_encounters_grade        object
# social_distancing_travel_distance_grade   object
# daily_state_test                         float64
# precipitation                            float64
# temperature                              float64
# ventilator_capacity_ratio                float64
# icu_beds_ratio                           float64
# Religious_congregation_ratio             float64
# percent_insured                          float64
# deaths_per_100000                        float64

# %% [markdown]
# ### SimpleImputer - Categorical Columns

# %%
cat_cols = ["social_distancing_total_grade", "social_distancing_visitation_grade",
            "social_distancing_encounters_grade", "social_distancing_travel_distance_grade"]

# %%
cat_to_impute = new_data[[i for i in cat_cols]]

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = "most_frequent")
imputed_cat_data = pd.DataFrame(imputer.fit_transform(cat_to_impute), columns = cat_to_impute.columns)

# %%
imputed_cat_data
# Out:
#        social_distancing_total_grade social_distancing_visitation_grade  \
# 0                                  F                                  F
# 1                                  F                                  F
# 2                                  F                                  F
# 3                                  F                                  F
# 4                                  F                                  F
# ...                              ...                                ...
# 557821                            D+                                  F
# 557822                            D+                                  F
# 557823                            D+                                  F
# 557824                            D+                                  F
# 557825                            D+                                  F
#
#        social_distancing_encounters_grade  \
# 0                                       F
# 1                                       F
# 2                                       F
# 3                                       F
# 4                                       F
# ...                                   ...
# 557821                                  A
# 557822                                  A
# 557823                                  A
# 557824                                  A
# 557825                                  A
#
#        social_distancing_travel_distance_grade
# 0                                            F
# 1                                            F
# 2                                            F
# 3                                            F
# 4                                            F
# ...                                        ...
# 557821                                       F
# 557822                                       F
# 557823                                       F
# 557824                                       F
# 557825                                       F
#
# [557826 rows x 4 columns]

# %% [markdown]
# ### KNN - Numerical Columns

# %%
num_cols = ["daily_state_test", "precipitation", "temperature", "ventilator_capacity_ratio",
           "icu_beds_ratio", "Religious_congregation_ratio", "percent_insured",
           "deaths_per_100000"]

# %%
num_to_impute = new_data[[i for i in num_cols]]

# %%
imputer = KNNImputer(n_neighbors=5)
imputed_col_data = pd.DataFrame(imputer.fit_transform(num_to_impute), columns = num_to_impute.columns)

# %% [markdown]
# ## Merge Imputed Data

# %%
non_null_features = list(set(new_data.columns)-set(null_features[0]))
non_null_data = new_data[[i for i in non_null_features]]

# %%
imputed_data = pd.concat([non_null_data, imputed_cat_data, imputed_col_data], axis = 1)
imputed_data
# Out:
#         less_than_high_school_diploma  airport_distance  age_50_54  \
# 0                                 9.7         58.533710          7
# 1                                 9.7         58.533710          7
# 2                                 9.7         58.533710          7
# 3                                 9.7         58.533710          7
# 4                                 9.7         58.533710          7
# ...                               ...               ...        ...
# 557821                            9.0        172.698662          8
# 557822                            9.0        172.698662          8
# 557823                            9.0        172.698662          8
# 557824                            9.0        172.698662          8
# 557825                            9.0        172.698662          8
#
#         covid_19_deaths   longitude  houses_density  age_35_39  \
# 0                   0.0  -87.722071         73.3630          6
# 1                   0.0  -87.722071         73.3630          6
# 2                   0.0  -87.722071         73.3630          6
# 3                   0.0  -87.722071         73.3630          6
# 4                   0.0  -87.722071         73.3630          6
# ...                 ...         ...             ...        ...
# 557821              0.0 -108.882788          1.9024          6
# 557822              0.0 -108.882788          1.9024          6
# 557823              0.0 -108.882788          1.9024          6
# 557824              0.0 -108.882788          1.9024          6
# 557825              0.0 -108.882788          1.9024          6
#
#         percent_diabetes  state_fips      date  ...  \
# 0                   10.7           1  01/22/20  ...
# 1                   10.7           1  01/23/20  ...
# 2                   10.7           1  01/24/20  ...
# 3                   10.7           1  01/25/20  ...
# 4                   10.7           1  01/26/20  ...
# ...                  ...         ...       ...  ...
# 557821               8.8          56  09/12/20  ...
# 557822               8.8          56  09/13/20  ...
# 557823               8.8          56  09/14/20  ...
# 557824               8.8          56  09/15/20  ...
# 557825               8.8          56  09/16/20  ...
#
#         social_distancing_encounters_grade  \
# 0                                        F
# 1                                        F
# 2                                        F
# 3                                        F
# 4                                        F
# ...                                    ...
# 557821                                   A
# 557822                                   A
# 557823                                   A
# 557824                                   A
# 557825                                   A
#
#         social_distancing_travel_distance_grade  daily_state_test  \
# 0                                             F            4580.0
# 1                                             F            4483.0
# 2                                             F            5397.6
# 3                                             F            3891.0
# 4                                             F            2591.0
# ...                                         ...               ...
# 557821                                        F              33.0
# 557822                                        F              49.0
# 557823                                        F            2569.0
# 557824                                        F             739.0
# 557825                                        F             224.0
#
#         precipitation  temperature  ventilator_capacity_ratio  icu_beds_ratio  \
# 0                 0.0          2.0                   0.000261        0.000234
# 1                 0.0          4.7                   0.000261        0.000234
# 2                79.0         11.4                   0.000261        0.000234
# 3                 0.0         10.0                   0.000261        0.000234
# 4                 5.0         10.8                   0.000261        0.000234
# ...               ...          ...                        ...             ...
# 557821            0.0         11.1                   0.000325        0.000302
# 557822            0.0         12.5                   0.000325        0.000302
# 557823            0.0         14.8                   0.000325        0.000302
# 557824            0.0         15.3                   0.000325        0.000302
# 557825            0.0         14.7                   0.000325        0.000302
#
#         Religious_congregation_ratio  percent_insured  deaths_per_100000
# 0                               53.0        88.666596             1081.1
# 1                               53.0        88.666596             1081.1
# 2                               53.0        88.666596             1081.1
# 3                               53.0        88.666596             1081.1
# 4                               53.0        88.666596             1081.1
# ...                              ...              ...                ...
# 557821                          48.0        85.535005              752.6
# 557822                          48.0        85.535005              752.6
# 557823                          48.0        85.535005              752.6
# 557824                          48.0        85.535005              752.6
# 557825                          48.0        85.535005              752.6
#
# [557826 rows x 59 columns]

# %%
imputed_data.isnull().mean()*100
# Out:
# less_than_high_school_diploma              0.0
# airport_distance                           0.0
# age_50_54                                  0.0
# covid_19_deaths                            0.0
# longitude                                  0.0
# houses_density                             0.0
# age_35_39                                  0.0
# percent_diabetes                           0.0
# state_fips                                 0.0
# date                                       0.0
# high_school_diploma_only                   0.0
# percent_smokers                            0.0
# age_65_69                                  0.0
# age_60_64                                  0.0
# age_15_19                                  0.0
# meat_plants                                0.0
# female_percent                             0.0
# index                                      0.0
# county_fips                                0.0
# median_household_income                    0.0
# age_10_14                                  0.0
# total_population                           0.0
# age_80_84                                  0.0
# age_75_79                                  0.0
# covid_19_confirmed_cases                   0.0
# hospital_beds_ratio                        0.0
# some_college_or_higher                     0.0
# immigrant_student_ratio                    0.0
# age_70_74                                  0.0
# age_0_4                                    0.0
# latitude                                   0.0
# age_55_59                                  0.0
# population_density                         0.0
# age_20_24                                  0.0
# county_name                                0.0
# age_40_44                                  0.0
# age_5_9                                    0.0
# total_college_population                   0.0
# political_party                            0.0
# state_name                                 0.0
# age_45_49                                  0.0
# gdp_per_capita                             0.0
# age_25_29                                  0.0
# age_85_or_higher                           0.0
# passenger_load_ratio                       0.0
# age_30_34                                  0.0
# area                                       0.0
# social_distancing_total_grade              0.0
# social_distancing_visitation_grade         0.0
# social_distancing_encounters_grade         0.0
# social_distancing_travel_distance_grade    0.0
# daily_state_test                           0.0
# precipitation                              0.0
# temperature                                0.0
# ventilator_capacity_ratio                  0.0
# icu_beds_ratio                             0.0
# Religious_congregation_ratio               0.0
# percent_insured                            0.0
# deaths_per_100000                          0.0
# dtype: float64

# %% [markdown]
# ## Export Imputed Data as CSV

# %%
compression_opts = dict(method='zip',archive_name='imputed_data.csv')

# %%
imputed_data.to_csv("/Users/Huey.ts/Desktop/STAT_390/data/imputed_data.zip",compression=compression_opts)
