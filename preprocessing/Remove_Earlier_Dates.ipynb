# %%
import pandas as pd

# %%
# Import train data
ne_train = pd.read_csv("../data/old_ver/ne_train.csv")
s_train = pd.read_csv("../data/old_ver/s_train.csv")

# %%
ne_train[ne_train.date == "2020-03-02"]
# Out:
#           date  cat__social_distancing_total_grade_B  \
# 40  2020-03-02                                   0.0
#
#     cat__social_distancing_total_grade_C  \
# 40                                   0.0
#
#     cat__social_distancing_total_grade_C+  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_C-  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_D  \
# 40                                   0.0
#
#     cat__social_distancing_total_grade_D+  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_F  \
# 40                                   1.0
#
#     cat__social_distancing_visitation_grade_A  \
# 40                                        0.0
#
#     cat__social_distancing_visitation_grade_F  ...  num__age_85_or_higher  \
# 40                                        1.0  ...           4.440892e-16
#
#     num__immigrant_student_ratio  num__weekend  \
# ...

# %%
s_train[s_train.date == "2020-03-02"]
# Out:
#           date  cat__social_distancing_total_grade_B  \
# 40  2020-03-02                                   0.0
#
#     cat__social_distancing_total_grade_C  \
# 40                                   0.0
#
#     cat__social_distancing_total_grade_C-  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_D  \
# 40                                   0.0
#
#     cat__social_distancing_total_grade_D+  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_D-  \
# 40                                    0.0
#
#     cat__social_distancing_total_grade_F  \
# 40                                   1.0
#
#     cat__social_distancing_visitation_grade_F  \
# 40                                        1.0
#
#     cat__social_distancing_encounters_grade_A  ...  num__age_85_or_higher  \
# 40                                        0.0  ...          -6.661338e-16
#
#     num__immigrant_student_ratio  num__weekend  \
# ...

# %%
ne_train = ne_train.iloc[40:]

# %%
s_train = s_train.iloc[40:]

# %%
ne_train.reset_index(inplace = True, drop = True)

# %%
s_train.reset_index(inplace = True, drop = True)

# %%
ne_train[ne_train.covid_19_confirmed_cases == 0]
# Out:
# Empty DataFrame
# ...

# %%
s_train[s_train.covid_19_confirmed_cases == 0]
# Out:
#          date  cat__social_distancing_total_grade_B  \
# 2  2020-03-04                                   0.0
#
#    cat__social_distancing_total_grade_C  \
# 2                                   0.0
#
#    cat__social_distancing_total_grade_C-  \
# 2                                    0.0
#
#    cat__social_distancing_total_grade_D  \
# 2                                   0.0
#
#    cat__social_distancing_total_grade_D+  \
# 2                                    0.0
#
#    cat__social_distancing_total_grade_D-  \
# 2                                    0.0
#
#    cat__social_distancing_total_grade_F  \
# 2                                   1.0
#
#    cat__social_distancing_visitation_grade_F  \
# 2                                        1.0
#
#    cat__social_distancing_encounters_grade_A  ...  num__age_85_or_higher  \
# 2                                        0.0  ...          -6.661338e-16
#
#    num__immigrant_student_ratio  num__weekend  \
# ...

# %%
s_train.replace({"covid_19_confirmed_cases": {0:1}}, inplace = True)

# %%
ne_train.to_csv("/Users/Huey.ts/Desktop/STAT_390/data/ne_train.csv")

# %%
s_train.to_csv("/Users/Huey.ts/Desktop/STAT_390/data/s_train.csv")
